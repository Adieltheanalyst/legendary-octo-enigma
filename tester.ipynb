# %%
import os
os.environ["XDG_CACHE_HOME"] = r"C:\whisper_cache"

# %%
import whisper
os.environ["PATH"] += os.pathsep + r"C:\Users\gacha\Downloads\ffmpeg-2025-11-17-git-e94439e49b-essentials_build\ffmpeg-2025-11-17-git-e94439e49b-essentials_build\bin"

model=whisper.load_model("base")
result=model.transcribe(r"c:\Users\gacha\OneDrive\Documentos\Sound Recordings\Recording (7).m4a",fp16=False)

# %%
print(result["text"])
# Out:
#  Hello, good morning. My name is Adil Hugi-Maina, I'm a student at the University of Nairobi. In campus, I do economics and statistics. Yeah, that's all. I am trying to test these are just our ways for my app. I want to see how well it can trust practice holding. Yeah, and that's all. Thank you.

# %%
import speech_recognition as sr
r= sr.Recognizer()
with sr.AudioFile(r"C:\Users\gacha\output.wav") as source:
    audio_text=r.listen(source)
r.recognize_google(audio_text)
# Out:
# 'hello good morning my name is'
